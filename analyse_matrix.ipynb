# %% [markdown]
# <a href="https://colab.research.google.com/github/aparna-2001/matrix-properties-calculator/blob/main/analyse_matrix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#wrapping in a single function


import numpy as np
import pandas as pd
import csv

def analyze_matrix(file_path):
    #file input
    data = pd.read_csv(file_path) #replace with your file name
    print(data)

    #To table
    data_table = pd.DataFrame(data)
    print(f"The data in table:{data_table}")

    #conversion to matrix
    def conversion_to_matrix(data):
        matrix_array = np.array(data)
        print(f"Converted matrix: {matrix_array}")
        return matrix_array

    # Call the conversion function and store the result
    matrix_input = conversion_to_matrix(data)

    #finding the rank
    def matrix_rank(matrix_input):
        matrix_rank = np.linalg.matrix_rank(matrix_input)
        print(f"Rank of matrix: {matrix_rank}")
        return matrix_rank

    matrix_rank(matrix_input)

    if matrix_input.shape[0]==matrix_input.shape[1]:
        Eigen_values,Eigen_matrix = np.linalg.eig(matrix_input) #Eigen values
        print(f"Eigen values of the matrix: {Eigen_values}")
        print(f"Eigen vectors of the matrix: {Eigen_matrix}")

        matrix_1_det = np.linalg.det(matrix_input) #determinant
        print(f"Determinant of the matrix: {matrix_1_det}")

        if matrix_1_det != 0:
            matrix_inverse = np.linalg.inv(matrix_input) #inverse
            print(f"Inverse of the matrix: {matrix_inverse}")
        else:
            print("Inverse doesn't exist: The matrix is singular or the matrix is a non square matrix")
    else:
        print("Matrix is not square, cannot calculate determinant, inverse, or eigen values/vectors.")
